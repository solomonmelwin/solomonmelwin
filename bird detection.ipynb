# %% [markdown]
# <a href="https://colab.research.google.com/github/solomonmelwin/solomonmelwin/blob/main/bird%20detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ✅ Install Required Packages in Colab
# !pip install tensorflow numpy matplotlib pillow scikit-learn albumentations
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (3.12.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import os
import numpy as np
import tensorflow as tf
import json
import matplotlib.pyplot as plt
from tensorflow.keras.applications import MobileNetV3Small, ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight

# %%
# !unzip -q /content/bird-dataset-split.zip -d /content/bird-dataset-split

# %%
import os

dataset_path = "/content/bird-dataset-split/train"  # Update if needed
class_counts = {cls: len(os.listdir(os.path.join(dataset_path, cls))) for cls in os.listdir(dataset_path)}

for bird_class, count in class_counts.items():
    print(f"{bird_class}: {count} images")
# Out:
# Indian Spot-billed Duck: 700 images
# greater flamingo: 700 images
# Lesser Whistling Duck: 700 images
# Fulvous Whistling Duck: 700 images
# spot billed pelican: 700 images
# Knob-billed Duck: 700 images
# glossy ibis: 700 images
# Graganey: 700 images
# Common Pochard: 700 images
# Eurasian Wigeon: 700 images
# eurasian spoonbill: 700 images
# Bar-headed Goose: 700 images
# Northern Pintail: 700 images
# black headed ibis: 700 images
# Tufted Duck: 700 images
# great white pelican: 700 images
# asian openbill: 700 images
# Northern Shoveler: 700 images
# Green-winged Teal: 700 images
# painted stork: 700 images

# %%
# ✅ Define Dataset Paths
dataset_path = "/content/bird-dataset-split"
batch_size = 32
img_size = (224, 224)

# ✅ Load Dataset with Class Order Preserved
train_dataset = image_dataset_from_directory(f"{dataset_path}/train", shuffle=True, batch_size=batch_size, image_size=img_size)
val_dataset = image_dataset_from_directory(f"{dataset_path}/val", shuffle=True, batch_size=batch_size, image_size=img_size)
test_dataset = image_dataset_from_directory(f"{dataset_path}/test", shuffle=False, batch_size=batch_size, image_size=img_size)

# ✅ Save Class Names for Later Use
class_names = train_dataset.class_names
num_classes = len(class_names)
with open("class_names.json", "w") as f:
    json.dump(class_names, f)

print("✅ Loaded Class Names:", class_names)
# Out:
# Found 14000 files belonging to 20 classes.
# Found 3021 files belonging to 20 classes.
# Found 2973 files belonging to 20 classes.
# ✅ Loaded Class Names: ['Bar-headed Goose', 'Common Pochard', 'Eurasian Wigeon', 'Fulvous Whistling Duck', 'Graganey', 'Green-winged Teal', 'Indian Spot-billed Duck', 'Knob-billed Duck', 'Lesser Whistling Duck', 'Northern Pintail', 'Northern Shoveler', 'Tufted Duck', 'asian openbill', 'black headed ibis', 'eurasian spoonbill', 'glossy ibis', 'great white pelican', 'greater flamingo', 'painted stork', 'spot billed pelican']

# %%
# ✅ Apply Data Augmentation to Training Data
augment_layer = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.3),
    tf.keras.layers.RandomZoom(0.3),
    tf.keras.layers.RandomContrast(0.4),
    tf.keras.layers.RandomTranslation(0.2, 0.2),
    tf.keras.layers.RandomBrightness(0.3),
    tf.keras.layers.RandomShear(0.3)
])
train_dataset = train_dataset.map(lambda x, y: (augment_layer(x), y), num_parallel_calls=tf.data.AUTOTUNE)

# %%
# ✅ Compute Class Weights to Avoid Class Bias
label_list = []
for images, labels in train_dataset.unbatch():
    label_list.append(labels.numpy())

all_labels = np.array(label_list)
class_weights = compute_class_weight("balanced", classes=np.unique(all_labels), y=all_labels)
class_weight_dict = dict(enumerate(class_weights))

print("✅ Computed Class Weights:", class_weight_dict)
# Out:
# ✅ Computed Class Weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0), 4: np.float64(1.0), 5: np.float64(1.0), 6: np.float64(1.0), 7: np.float64(1.0), 8: np.float64(1.0), 9: np.float64(1.0), 10: np.float64(1.0), 11: np.float64(1.0), 12: np.float64(1.0), 13: np.float64(1.0), 14: np.float64(1.0), 15: np.float64(1.0), 16: np.float64(1.0), 17: np.float64(1.0), 18: np.float64(1.0), 19: np.float64(1.0)}

# %%
# ✅ Load Pretrained Models
base_model_mobilenet = MobileNetV3Small(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
base_model_resnet = ResNet50(input_shape=(224, 224, 3), include_top=False, weights="imagenet")

# ✅ Unfreeze Some Layers for Fine-Tuning **EARLIER**
for layer in base_model_mobilenet.layers[-75:]:
    layer.trainable = True
for layer in base_model_resnet.layers[-75:]:
    layer.trainable = True

# ✅ Define Model Architecture
input_layer = Input(shape=(224, 224, 3))
x1 = base_model_mobilenet(input_layer, training=False)
x1 = GlobalAveragePooling2D()(x1)
x1 = BatchNormalization()(x1)  # ✅ Normalize features

x2 = base_model_resnet(input_layer, training=False)
x2 = GlobalAveragePooling2D()(x2)
x2 = BatchNormalization()(x2)  # ✅ Normalize features

x = Concatenate()([x1, x2])
x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)  # ✅ Normalize fully connected layers
x = Dropout(0.5)(x)
out = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=input_layer, outputs=out)

import tensorflow as tf

# Function to convert integer labels to one-hot encoding
def one_hot_encode(image, label):
    label = tf.one_hot(label, depth=num_classes)  # Convert to one-hot
    return image, label

# Apply one-hot encoding to datasets
train_dataset = train_dataset.map(one_hot_encode)
val_dataset = val_dataset.map(one_hot_encode)
test_dataset = test_dataset.map(one_hot_encode)

# ✅ Now, your dataset outputs one-hot labels and works with CategoricalCrossentropy


# ✅ Use Label Smoothing to Reduce Overconfidence
loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss=loss_fn,
              metrics=["accuracy"])

print("✅ Model Built Successfully!")
# Out:
# ✅ Model Built Successfully!

# %%
# ✅ Train Model with Early Stopping & Class Weights
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint("best_model.h5", save_best_only=True)
]

history = model.fit(train_dataset, validation_data=val_dataset, epochs=20, class_weight=class_weight_dict, callbacks=callbacks)

# ✅ Save Model Properly (Avoid Optimizer Mismatch Issue)
model.save("final_bird_model.keras", save_traces=False)
# Out:
# Epoch 1/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.2215 - loss: 3.3911
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 448s 759ms/step - accuracy: 0.2217 - loss: 3.3900 - val_accuracy: 0.5174 - val_loss: 2.1932
# Epoch 2/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.4712 - loss: 2.2095
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 284s 646ms/step - accuracy: 0.4712 - loss: 2.2092 - val_accuracy: 0.6031 - val_loss: 1.9263
# Epoch 3/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.5775 - loss: 1.8382
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 318s 635ms/step - accuracy: 0.5776 - loss: 1.8381 - val_accuracy: 0.7100 - val_loss: 1.4791
# Epoch 4/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.6701 - loss: 1.5984
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 322s 636ms/step - accuracy: 0.6702 - loss: 1.5983 - val_accuracy: 0.7789 - val_loss: 1.3595
# Epoch 5/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 272s 619ms/step - accuracy: 0.7219 - loss: 1.4451 - val_accuracy: 0.7650 - val_loss: 1.3865
# Epoch 6/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.7766 - loss: 1.3342
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 279s 634ms/step - accuracy: 0.7766 - loss: 1.3342 - val_accuracy: 0.8087 - val_loss: 1.2932
# Epoch 7/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.8087 - loss: 1.2340
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 279s 634ms/step - accuracy: 0.8087 - loss: 1.2340 - val_accuracy: 0.8540 - val_loss: 1.1381
# Epoch 8/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 312s 611ms/step - accuracy: 0.8374 - loss: 1.1651 - val_accuracy: 0.8616 - val_loss: 1.1433
# Epoch 9/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.8582 - loss: 1.1069
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 277s 631ms/step - accuracy: 0.8582 - loss: 1.1068 - val_accuracy: 0.9030 - val_loss: 1.0541
# Epoch 10/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 273s 622ms/step - accuracy: 0.8763 - loss: 1.0631 - val_accuracy: 0.8663 - val_loss: 1.1061
# Epoch 11/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.8881 - loss: 1.0183
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 328s 633ms/step - accuracy: 0.8881 - loss: 1.0182 - val_accuracy: 0.9136 - val_loss: 1.0017
# Epoch 12/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 313s 614ms/step - accuracy: 0.8990 - loss: 0.9974 - val_accuracy: 0.9073 - val_loss: 1.0116
# Epoch 13/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 392s 774ms/step - accuracy: 0.9152 - loss: 0.9578 - val_accuracy: 0.8977 - val_loss: 1.0103
# Epoch 14/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 313s 617ms/step - accuracy: 0.9170 - loss: 0.9435 - val_accuracy: 0.8779 - val_loss: 1.0842
# Epoch 15/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.9178 - loss: 0.9350
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 277s 630ms/step - accuracy: 0.9179 - loss: 0.9349 - val_accuracy: 0.9278 - val_loss: 0.9493
# Epoch 16/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.9355 - loss: 0.8983
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 347s 790ms/step - accuracy: 0.9355 - loss: 0.8982 - val_accuracy: 0.9255 - val_loss: 0.9214
# Epoch 17/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.9364 - loss: 0.8873
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 273s 622ms/step - accuracy: 0.9364 - loss: 0.8873 - val_accuracy: 0.9421 - val_loss: 0.9074
# Epoch 18/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9490 - loss: 0.8609
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 277s 631ms/step - accuracy: 0.9490 - loss: 0.8609 - val_accuracy: 0.9441 - val_loss: 0.8917
# Epoch 19/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 269s 611ms/step - accuracy: 0.9447 - loss: 0.8577 - val_accuracy: 0.9245 - val_loss: 0.9152
# Epoch 20/20
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 332s 757ms/step - accuracy: 0.9593 - loss: 0.8315 - val_accuracy: 0.9265 - val_loss: 0.8922
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-c13ba82c7df8> in <cell line: 0>()
#       8
#       9 # ✅ Save Model Properly (Avoid Optimizer Mismatch Issue)
# ---> 10 model.save("final_bird_model.keras", save_traces=False)
#      11
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in save_model(model, filepath, overwrite, zipped, **kwargs)
#      74             )
#      75     if kwargs:
# ---> 76         raise ValueError(
#      77             "The following argument(s) are not supported: "
#      78             f"{list(kwargs.keys())}"
#
# ValueError: The following argument(s) are not supported: ['save_traces']

# %%
model.save("final_bird_model.keras")  # ✅ Correct way to save

# %%
# ✅ Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# ✅ Save the TFLite model
with open("bird_model.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ TFLite model saved as bird_model.tflite")

# ✅ Plot Training Curves
def plot_training_curves(history):
    plt.figure(figsize=(12, 5))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label="Train Accuracy", color="blue")
    plt.plot(history.history['val_accuracy'], label="Validation Accuracy", color="red")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Training vs Validation Accuracy")

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label="Train Loss", color="blue")
    plt.plot(history.history['val_loss'], label="Validation Loss", color="red")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Training vs Validation Loss")

    plt.show()

# ✅ Run this after training
plot_training_curves(history)

# ✅ Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"✅ Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Saved artifact at '/tmp/tmpgqpfon6x'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_3320')
# Output Type:
#   TensorSpec(shape=(None, 20), dtype=tf.float32, name=None)
# Captures:
#   138260434115024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434115600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434115792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434114640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434111184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434115408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434119632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434120208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434120400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434119248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434112720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434120016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434121936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434122512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434122704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434121552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434116176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434122320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434124240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434124432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434117328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434117904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434116944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434108880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434117712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434124624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312517904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434123088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434120784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312519440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312520016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312520208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312519056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312518672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312519824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312521744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312522320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312522512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312521360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312517712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312522128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312524048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312524624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312524816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312523664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312518096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312524432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312526352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312526928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312527120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312525968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312520592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312526736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312528656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312529232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312529424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312528272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312522896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312529040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312530960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312531536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312531728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312530576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312525200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312531344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312945232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312945808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312946000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312943888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312944464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312945616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312947536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312948112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312948304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312947152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312944848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312950416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312533264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312533648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312532496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312944080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312532112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312533840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312950608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312949456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312944656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312950224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312952144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312952720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312952912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312951760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312952528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312954448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312955024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312955216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312954064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312948688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312956752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312957328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312957520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312956368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312950992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312957136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312959056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312959632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312958288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312957904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312953296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262312958672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458964368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458964944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458965136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458963792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458963216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458964752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458966672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458967248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458967440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458966288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458963984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458967056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458968976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458969552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458969744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458968592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458963024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458969360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458971280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458971856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458972048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458970896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458965520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458971664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458973584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458974160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458974352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458973200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458967824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458973968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458978192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458978768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458977040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458974736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458972432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458977808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459143440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459144976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459145168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459144400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459143632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459144784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459146704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459147280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458975888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458976464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458976656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458975504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458970128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260458976272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459147472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459146320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459144016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459147088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459149008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459149584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459149776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459148624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459144208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459149392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459151312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459151888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459152080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459150928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459145552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459151696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459153616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459154192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459154384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459153232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459147856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459154000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459155920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459156496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459156688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459155536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459150160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459156304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459158224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459158800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459159376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459157456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459152464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459158608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260459154768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456423888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456423504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456424848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456426768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456427344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456427536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456424080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456427152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456429072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456429648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456431184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456424272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456433104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456433680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456433872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456425616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456433488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456434256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456434448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456430992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456431952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456434064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456435984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456436560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456436752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456435600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456431760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456436368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456438288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456438864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456439440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456434832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456438672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456437520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456965520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456964752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456964176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456964560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456965328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456967248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456967824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456968016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456966864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456964944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456967632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456969552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456970128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456970320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456969168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456965712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456969936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456974160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456974736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456974928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456973776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456968400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456974544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456976464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456977040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456977232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456976080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456970704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456976848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456978768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456979344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456971856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456972432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456972624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456971472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456966096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456972240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456979536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456980304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456973008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456979152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456977616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456975312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456308816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456309392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456310160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456309776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456311696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456312272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456312464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456311312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456309968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456312080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456314000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456314576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456314768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456313616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456309200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456314384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456316304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456316880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456317072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456315920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456310544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456316688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456318608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456319184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456319376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456318224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456312848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456318992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456320912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456321488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456321680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456320528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456315152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456321296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978648976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978651088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978649936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978652048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978648016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978653584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978649168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978652624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978652432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978650128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978646096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978646288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978647056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978644752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978645712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978650320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372678160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978645904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261978650896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372664720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372676624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372676816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372677008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372672016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372673360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372677584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372672592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372672208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372678352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372672400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372676048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372678928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372675856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372679120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372675472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372674128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372671632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372675088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372666640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372673936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372674704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372677776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262372671824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976611536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976609424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976596752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976611152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976612304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976612688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976608464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260468397072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976609616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976609232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976611920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138261976612112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467239632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467239248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467238864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467237328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467245200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467244240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467245008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467236944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467246160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467239440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464623952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464624144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467245776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467244048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464625296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464625680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464626064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464625872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464623376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464627216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464627600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464627984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464627792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464623760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464629136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464629712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464628752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464630480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464629904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464630672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464620304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464631248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464626832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260464630288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467631312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467630736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467631504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467630544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467632848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467633232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467633616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467633424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467631696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467634768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467635344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467634384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467636112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467635536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467636688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467637072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467636880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467632464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467638224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467638608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467638992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467638800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467630928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467640144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467640528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467640912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467640720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467636304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467642064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467642640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467641680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467643408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467642832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467643984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467644368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467644176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467639760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467645520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467645136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467644752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467646096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467630352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260467643600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466926992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466927376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466925648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466928528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466929104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466928144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466929872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466929296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466930448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466930832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466930640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466931984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466932368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466932752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466932560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466926224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466933904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466934288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466934672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466934480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466930064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466935824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466936400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466935440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466937168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466936592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466937744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466938128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466937936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466933520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466939280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466939664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466940048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466939856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466941200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466941776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466940432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466941584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260466938896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434108688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434110224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434109648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434110992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434110416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434111568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434111952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434111760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434109456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434113104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434113488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434113872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434113680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260434109264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456322832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456322448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456322064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456323024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456319760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456317456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456323600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260456324752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260436926736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260436928272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260436928464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260436927120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260436927696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260436928080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260436926928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260436930960: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ TFLite model saved as bird_model.tflite
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - accuracy: 0.9464 - loss: 0.8701
# ✅ Test Accuracy: 94.32%

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# ✅ Get True Labels & Predictions
y_true = []
y_pred = []

for images, labels in test_dataset:
    preds = model.predict(images)
    y_true.extend(np.argmax(labels.numpy(), axis=1))  # Convert y_true to class indices
    y_pred.extend(np.argmax(preds, axis=1))  # Convert predictions to class indices

# ✅ Convert to NumPy Arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Now, `y_pred` matches `y_true`, so classification_report() works
print("✅ Classification Report:\n", classification_report(y_true, y_pred, target_names=class_names))

# ✅ Plot Confusion Matrix
plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# ✅ Classification Report:
#                           precision    recall  f1-score   support
#
#        Bar-headed Goose       0.94      0.96      0.95       122
#          Common Pochard       0.96      0.94      0.95       157
#         Eurasian Wigeon       0.93      0.98      0.95       157
#  Fulvous Whistling Duck       0.95      0.98      0.96       163
#                Graganey       0.97      0.95      0.96       164
#       Green-winged Teal       0.94      0.96      0.95       150
# Indian Spot-billed Duck       0.91      0.95      0.93       152
#        Knob-billed Duck       0.99      0.89      0.94       155
#   Lesser Whistling Duck       0.96      0.84      0.89       160
#        Northern Pintail       0.94      0.97      0.95       139
#       Northern Shoveler       0.96      0.99      0.98       165
#             Tufted Duck       0.99      0.94      0.96       145
#          asian openbill       0.94      0.82      0.88       136
#       black headed ibis       0.95      0.94      0.94       117
#      eurasian spoonbill       0.98      0.92      0.95       147
#             glossy ibis       0.93      0.98      0.95       168
#     great white pelican       0.94      0.91      0.93       141
#        greater flamingo       0.98      0.98      0.98       132
#           painted stork       0.97      0.97      0.97       149
#     spot billed pelican       0.80      0.99      0.88       154
#
#                accuracy                           0.94      2973
#               macro avg       0.95      0.94      0.94      2973
#            weighted avg       0.95      0.94      0.94      2973

# %%
model.save("bird_classification_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

# Load your trained model
model = load_model("/content/final_bird_model.keras")

print("✅ Model loaded successfully!")
# Out:
# ✅ Model loaded successfully!
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 362 variables whereas the saved optimizer has 722 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

def load_and_preprocess_image(image_path):
    img = cv2.imread(image_path)  # Load image
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, (224, 224))  # Resize to 224x224 (for MobileNetV3)
    img = preprocess_input(img)  # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# %%
# Provide the path to your test bird image
test_image_path = "/content/download.jpeg"  # Change this to your test image

# Preprocess the image
input_img = load_and_preprocess_image(test_image_path)

# Predict the bird species
predictions = model.predict(input_img)

# Get the class with the highest probability
predicted_class_index = np.argmax(predictions)

# Update this list with your actual class names (same as training classes)
class_labels = ['Bar-headed Goose', 'Common Pochard', 'Eurasian Wigeon', 'Fulvous Whistling Duck', 'Graganey', 'Green-winged Teal', 'Indian Spot-billed Duck', 'Knob-billed Duck', 'Lesser Whistling Duck', 'Northern Pintail', 'Northern Shoveler', 'Tufted Duck', 'asian openbill', 'black headed ibis', 'eurasian spoonbill', 'glossy ibis', 'great white pelican', 'greater flamingo', 'painted stork', 'spot billed pelican']

# Get the predicted class label
predicted_label = class_labels[predicted_class_index]

print(f"🦜 Predicted Bird Species: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 🦜 Predicted Bird Species: painted stork

# %%
# prompt: download this as tflite /content/final_bird_model.keras for app development

import tensorflow as tf

# Load your trained Keras model
model = tf.keras.models.load_model('/content/final_bird_model.keras')

# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model to a file
with open('bird_model.tflite', 'wb') as f:
  f.write(tflite_model)

from google.colab import files
files.download('bird_model.tflite')
# Out:
# Saved artifact at '/tmp/tmpdo3r49ex'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_9')
# Output Type:
#   TensorSpec(shape=(None, 20), dtype=tf.float32, name=None)
# Captures:
#   138260439162448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439163024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439163216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439155536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439162832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439164752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439165328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439165520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439164368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439158608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439165136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439167056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439167632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439167824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439166672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439156496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439167440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439168976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439170704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439169360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439169936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439169744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439163600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439165904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439170128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852689232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852689808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852688464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852688848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852691344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852691920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852692112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852690960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852688656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852691728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852693648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852694224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852694416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852693264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852689424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852694032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852695952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852696528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852696720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852695568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852690192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852696336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852698256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852698832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852699024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852697872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852692496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852698640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852700560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852701136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852701328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852700176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852694800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852700944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852702864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852703440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852703632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852704400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852697104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852703248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852702096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253852704016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268564304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268563728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268564112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268566224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268565840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268563920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268566608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268569872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268569104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268570064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268569296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268565072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268569680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268571216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268571600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268570448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268570832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268573136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268573712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268573904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268572752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268567376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268573520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268575440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268576016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268576208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268575056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268563536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268575824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268577744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268578320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268578512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268577360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268571984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268578128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268576976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268579664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834454032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834453456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254268574288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834453648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834456144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834456336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834455952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834457872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834458448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834458640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834457488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834453072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834458256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834460176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834460752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834460944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834459792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834454416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834460560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834462480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834463056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834463248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834462096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834456720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834462864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834464784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834465360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834464400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834459024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834461328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834463632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837435920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837435152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837435344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837436880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837438608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837437264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837437840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837438800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837438032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837436112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837438416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837439952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837440336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837439184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837439568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837441872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837442448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837442640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837441488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837435728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837442256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837444176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837444752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837444944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837443792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837434960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837444560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837446480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837447056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837447248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837446096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837440720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837446864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837448784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837449360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837449552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837448400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837443024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837449168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837451088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837450704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837484688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837484304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837449936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837445328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837486224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837486800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837486992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837485840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837484496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837486608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837488528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837489104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837489296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837488144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837485072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837488912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837490832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837491408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837491600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837490448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837484880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837491216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837493136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837493712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837493904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837492752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837487376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837493520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837495440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837496016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837496208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837495056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837489680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837495824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837497744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837498320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837498512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837497360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837491984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837498128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837500048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837499664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838368848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838369808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837498896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253837496592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838370768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838371344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838371536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838370384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838370000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838371152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838373072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838373648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838373840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838372688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838369616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838373456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838375376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838376144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838374992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838369424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838375760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838377680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838378256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838378448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838377296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838371920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838378064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838379984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838380560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838380752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838379600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838374224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838380368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838381904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838383632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838382288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838382864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838383824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838383056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838378832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838383440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838381136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842825296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838384976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253838382672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842827024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842827600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842827792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842826640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842826256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842827408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842829328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842829904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842830096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842828944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842825488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842829712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842831632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842832208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842832400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842831248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842825680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842832016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842833936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842834512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842834704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842833552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842828176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842834320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842836240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842836816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842837008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842835856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842830480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842836624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842838544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842839120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842839312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842838160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842832784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842838928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680257872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680254416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680257488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680248656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680251344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680250960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680259024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680264016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680256720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680249808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680259408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680260368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680261712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680258064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680257104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680256528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680252496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680255760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680262864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680251920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680250384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680247888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680249616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680255952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680259216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680256912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680254608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680257296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680254800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680249040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813155216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813157136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680261520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259680263824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813159056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813154448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813160592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813160208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813156944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813162896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813157904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813164432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813164048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813153872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813166736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813161744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813169424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813168272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813158288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813167504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813168848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813168080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813169616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813162128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813163280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813164240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813163856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813161360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813165968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813160016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813158096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813160400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813154640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813156560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813166928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813165008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813167312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813167696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813159248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813157328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813155408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813154832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813163664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264001040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263998928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253813167888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263998544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264003536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264005840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264003920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264007376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264006224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264007952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264001232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263997392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263992400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264007184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264004304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264003152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264004880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264000464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263998736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264002384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264008336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264002768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264007760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263993552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264001616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264002192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263996624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263997968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263996816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263996432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263995856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264000848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263995280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263994896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263994512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263993936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254264001808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262313838032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263993744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263997200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263995664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262313832656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254263996048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834747152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834745808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834747536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834746000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036597264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036604368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253834746384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036608400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036596880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036600336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036599376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036595152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036602064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036594960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036596496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036602832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036594768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036603600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036596112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036600912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036598608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036603216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036602640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036605520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036605136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036603792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036599568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036605904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036601488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036609360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036604176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036598224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036607824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036599952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036609744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036604560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036608208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036605328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036610896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036610512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036610128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036606864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675407824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675404944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036598992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138262036607248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675405712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675405904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675406096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675406480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675399184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675404176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675408208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675408016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675407248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675404752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675409360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675409936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675408976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675410704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675410128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675411280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675411664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675411472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675398992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675412816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675413200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675413584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675413392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675406288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675412048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439155344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439155728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675414352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138259675410896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439158032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439159376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439159952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439160528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439159568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439156112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439157648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439154960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439158416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439159184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439160912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439161296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439161104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138260439154768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842841232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842835088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842839696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842840080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262797328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262796944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138253842837392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262796752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262798672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262799248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262799440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262798288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262797136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262799056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262796560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138254262801936: TensorSpec(shape=(), dtype=tf.resource, name=None)
