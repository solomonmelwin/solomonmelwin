# %% [markdown]
# <a href="https://colab.research.google.com/github/solomonmelwin/solomonmelwin/blob/main/bird%20model%20deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import load_model

# Load your trained model
model = load_model("/content/final_bird_model.keras")

print("✅ Model loaded successfully!")
# Out:
# ✅ Model loaded successfully!
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 362 variables whereas the saved optimizer has 722 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

def load_and_preprocess_image(image_path):
    img = cv2.imread(image_path)  # Load image
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, (224, 224))  # Resize to 224x224 (for MobileNetV3)
    img = preprocess_input(img)  # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# %%
# Provide the path to your test bird image
test_image_path = "/content/download.jpeg"  # Change this to your test image

# Preprocess the image
input_img = load_and_preprocess_image(test_image_path)

# Predict the bird species
predictions = model.predict(input_img)

# Get the class with the highest probability
predicted_class_index = np.argmax(predictions)

# Update this list with your actual class names (same as training classes)
class_labels = ['Bar-headed Goose', 'Common Pochard', 'Eurasian Wigeon', 'Fulvous Whistling Duck', 'Graganey', 'Green-winged Teal', 'Indian Spot-billed Duck', 'Knob-billed Duck', 'Lesser Whistling Duck', 'Northern Pintail', 'Northern Shoveler', 'Tufted Duck', 'asian openbill', 'black headed ibis', 'eurasian spoonbill', 'glossy ibis', 'great white pelican', 'greater flamingo', 'painted stork', 'spot billed pelican']

# Get the predicted class label
predicted_label = class_labels[predicted_class_index]

print(f"🦜 Predicted Bird Species: {predicted_label}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72dfd4b7bffe> in <cell line: 0>()
#       3
#       4 # Preprocess the image
# ----> 5 input_img = load_and_preprocess_image(test_image_path)
#       6
#       7 # Predict the bird species
#
# NameError: name 'load_and_preprocess_image' is not defined

# %%
# prompt: lets develop in the way that the predicted species details will be displayed along with the user uploaded image

from tensorflow.keras.models import load_model
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from IPython.display import display, Image  # For displaying images in Colab

# Load your trained model
model = load_model("/content/final_bird_model.keras")

print("✅ Model loaded successfully!")


def load_and_preprocess_image(image_path):
    img = cv2.imread(image_path)  # Load image
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, (224, 224))  # Resize to 224x224 (for MobileNetV3)
    img = preprocess_input(img)  # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Update this list with your actual class names (same as training classes)
class_labels = ['Bar-headed Goose', 'Common Pochard', 'Eurasian Wigeon', 'Fulvous Whistling Duck', 'Graganey', 'Green-winged Teal', 'Indian Spot-billed Duck', 'Knob-billed Duck', 'Lesser Whistling Duck', 'Northern Pintail', 'Northern Shoveler', 'Tufted Duck', 'asian openbill', 'black headed ibis', 'eurasian spoonbill', 'glossy ibis', 'great white pelican', 'greater flamingo', 'painted stork', 'spot billed pelican']


def predict_bird_species(image_path):
    # Preprocess the image
    input_img = load_and_preprocess_image(image_path)

    # Predict the bird species
    predictions = model.predict(input_img)

    # Get the class with the highest probability
    predicted_class_index = np.argmax(predictions)

    # Get the predicted class label
    predicted_label = class_labels[predicted_class_index]

    # Display the image and prediction
    display(Image(filename=image_path))
    print(f"🦜 Predicted Bird Species: {predicted_label}")


# Provide the path to your test bird image
test_image_path = "/content/download.jpeg"  # Change this to your test image

# Predict and display the results
predict_bird_species(test_image_path)
# Out:
# ✅ Model loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 🦜 Predicted Bird Species: painted stork

# %%
# prompt: it is correct lets say I wish to give some details about the bird both in english and tamil

from tensorflow.keras.models import load_model
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from IPython.display import display, Image  # For displaying images in Colab

# Load your trained model
model = load_model("/content/final_bird_model.keras")

print("✅ Model loaded successfully!")


def load_and_preprocess_image(image_path):
    img = cv2.imread(image_path)  # Load image
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, (224, 224))  # Resize to 224x224 (for MobileNetV3)
    img = preprocess_input(img)  # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Update this list with your actual class names (same as training classes)
class_labels = ['Bar-headed Goose', 'Common Pochard', 'Eurasian Wigeon', 'Fulvous Whistling Duck', 'Graganey', 'Green-winged Teal', 'Indian Spot-billed Duck', 'Knob-billed Duck', 'Lesser Whistling Duck', 'Northern Pintail', 'Northern Shoveler', 'Tufted Duck', 'asian openbill', 'black headed ibis', 'eurasian spoonbill', 'glossy ibis', 'great white pelican', 'greater flamingo','painted stork', 'spot billed pelican']


def predict_bird_species(image_path):
    # Preprocess the image
    input_img = load_and_preprocess_image(image_path)

    # Predict the bird species
    predictions = model.predict(input_img)

    # Get the class with the highest probability
    predicted_class_index = np.argmax(predictions)

    # Get the predicted class label
    predicted_label = class_labels[predicted_class_index]

    # Display the image and prediction
    display(Image(filename=image_path))
    print(f"🦜 Predicted Bird Species: {predicted_label}")

# Add bird details (English and Tamil)
if predicted_label == "Bar-headed Goose":
    print("Scientific Name: Anser indicus")
    print("English Details: The Bar-headed Goose is known for its high-altitude migratory flights over the Himalayas.")
    print("Tamil Details: பார்முடி வாத்து அதன் இமயமலையை மீறி உயர்ந்த பறப்புகளுக்குப் புகழ் பெற்றது.")

elif predicted_label == "Common Pochard":
    print("Scientific Name: Aythya ferina")
    print("English Details: The Common Pochard is a medium-sized diving duck found in temperate regions.")
    print("Tamil Details: சாதாரண போச்சார்ட் என்பது மிதமான பகுதிகளில் காணப்படும் நடுத்தர அளவுள்ள மூழ்கும் வாத்து.")

elif predicted_label == "Eurasian Wigeon":
    print("Scientific Name: Mareca penelope")
    print("English Details: The Eurasian Wigeon is a dabbling duck with distinctive breeding plumage.")
    print("Tamil Details: யூரேஷியன் விட்ஜியன் என்பது தனித்துவமான இனப்பெருக்க இறகுகளைக் கொண்ட ஒரு வாத்து.")

elif predicted_label == "Fulvous Whistling Duck":
    print("Scientific Name: Dendrocygna bicolor")
    print("English Details: The Fulvous Whistling Duck is a long-legged duck found in warm freshwater marshes.")
    print("Tamil Details: ஃபுல்வஸ் விசில் வாத்து என்பது நீண்ட கால்களைக் கொண்ட, சூடான இனிய நீர்நிலைகளில் காணப்படும் வாத்து.")
    print("Source: https://www.allaboutbirds.org/guide/Fulvous_Whistling-Duck/overview")

elif predicted_label == "Garganey":
    print("Scientific Name: Spatula querquedula")
    print("English Details: The Garganey is a small dabbling duck that migrates from Europe and Asia to Africa.")
    print("Tamil Details: கார்கனி என்பது ஐரோப்பா மற்றும் ஆசியாவில் இருந்து ஆப்பிரிக்காவுக்கு இடம்பெயரும் ஒரு சிறிய வாத்து.")

elif predicted_label == "Green-winged Teal":
    print("Scientific Name: Anas crecca")
    print("English Details: The Green-winged Teal is one of the smallest dabbling ducks, known for its green wing patch.")
    print("Tamil Details: கிரீன்-விங்க்ட் டீல் என்பது அதன் பச்சை இறக்கை தழும்பிற்குப் புகழ் பெற்ற மிகச் சிறிய வாத்துகளில் ஒன்றாகும்.")

elif predicted_label == "Knob-billed Duck":
    print("Scientific Name: Sarkidiornis melanotos")
    print("English Details: The Knob-billed Duck, also known as the Comb Duck, is recognized by the distinctive knob on its bill.")
    print("Tamil Details: க்னாப்-பில்ல்ட் வாத்து அல்லது கோம்ப் வாத்து அதன் மூக்கில் உள்ள தனித்துவமான குன்றுக்குப் புகழ் பெற்றது.")

elif predicted_label == "Lesser Whistling Duck":
    print("Scientific Name: Dendrocygna javanica")
    print("English Details: The Lesser Whistling Duck is a nocturnal feeder often found in wetlands and rice fields.")
    print("Tamil Details: லெசர் விசில் வாத்து என்பது இரவு நேர உணவுக்குப் பழகிய, பொதுவாக ஈரநிலங்களிலும் நெல் வயல்களிலும் காணப்படும் வாத்து.")

elif predicted_label == "Northern Pintail":
    print("Scientific Name: Anas acuta")
    print("English Details: The Northern Pintail is a graceful duck with a long neck and pointed tail feathers.")
    print("Tamil Details: நார்தர்ன் பிண்டெயில் என்பது நீண்ட கழுத்து மற்றும் கூர்மையான வால் இறகுகளைக் கொண்ட ஒரு அழகிய வாத்து.")

elif predicted_label == "Tufted Duck":
    print("Scientific Name: Aythya fuligula")
    print("English Details: The Tufted Duck is a medium-sized diving duck with a distinctive head tuft.")
    print("Tamil Details: டஃப்டட் வாத்து என்பது தனித்துவமான தலை துடுப்பைக் கொண்ட நடுத்தர அளவுள்ள மூழ்கும் வாத்து.")

elif predicted_label == "Asian Openbill":
    print("Scientific Name: Anastomus oscitans")
    print("English Details: The Asian Openbill is a stork species characterized by the gap between its bill halves.")
    print("Tamil Details: ஆசிய ஓபன்பில் என்பது அதன் மூக்கு அரைபாகங்களுக்கிடையில் உள்ள இடைவெளியால் அறியப்படும் ஒரு நாரை இனமாகும்.")

elif predicted_label == "Black-headed Ibis":
    print("Scientific Name: Threskiornis melanocephalus")
    print("English Details: The Black-headed Ibis is a wading bird commonly found in marshes, swamps, and rice fields.")
    print("Tamil Details: கருப்பு தலை நாரை என்பது பொதுவாக சதுப்பு நிலங்கள், குளங்கள் மற்றும் நெல் வயல்களில் காணப்படும் ஒரு நீர்நிலைப் பறவை.")

elif predicted_label == "Eurasian Spoonbill":
    print("Scientific Name: Platalea leucorodia")
    print("English Details: The Eurasian Spoonbill is a wading bird known for its spoon-shaped bill used for foraging.")
    print("Tamil Details: யூரேஷியன் ஸ்பூன்பில் என்பது அதன் கரண்டி வடிவ மூக்கிற்குப் புகழ் பெற்ற ஒரு நீர்நிலைப் பறவை.")

elif predicted_label == "Glossy Ibis":
    print("Scientific Name: Plegadis falcinellus")
    print("English Details: The Glossy Ibis is a dark-colored wading bird with iridescent plumage.")
    print("Tamil Details: க்ளாசி ஐபிஸ் என்பது பளிச்சிடும் இறகுகளைக் கொண்ட இருண்ட நிற நீர்நிலைப் பறவை.")

elif predicted_label == "Great White Pelican":
    print("Scientific Name: Pelecanus onocrotalus")
    print("English Details: The Great White Pelican is one of the largest flying birds, known for its large throat pouch.")
    print("Tamil Details: கிரேட் வைட் பெலிகன் என்பது அதன் பெரிய தொண்டை பைகளுக்குப் புகழ் பெற்ற மிகப்பெரிய பறக்கும் பறவைகளில் ஒன்றாகும்.")

elif predicted_label == "Greater Flamingo":
    print("Scientific Name: Phoenicopterus roseus")
    print("English Details: The Greater Flamingo is the largest species of flamingo, recognized by its pink plumage.")
    print("Tamil Details: கிரேட்டர் ஃபிளாமிங்கோ என்பது அதன் இளஞ்சிவப்பு இறகுகளால் அறியப்படும் மிகப்பெரிய ஃபிளாமிங்கோ இனமாகும்.")
elif predicted_label == "Painted Stork":
    print("Scientific Name: Mycteria leucocephala")
    print("English Details: The Painted Stork is a large wading bird known for its bright pink tertial feathers and long yellow beak.")
    print("Tamil Details: அலங்கார நாரை என்பது அதன் பிரகாசமான இளஞ்சிவப்பு இறக்கைகள் மற்றும் நீண்ட மஞ்சள் மூக்கிற்குப் புகழ் பெற்ற பெரிய நீர்நிலைப் பறவை.")

elif predicted_label == "Spot-billed Pelican":
    print("Scientific Name: Pelecanus philippensis")
    print("English Details: The Spot-billed Pelican is a large waterbird with a distinctive spotted bill, commonly found in wetlands and lakes.")
    print("Tamil Details: ஸ்பாட்-பில்ல்ட் பெலிகன் என்பது தனித்துவமான புள்ளி மூக்கைக் கொண்ட ஒரு பெரிய நீர்நிலைப் பறவை, பொதுவாக ஈரநிலங்கள் மற்றும் ஏரிகளில் காணப்படுகிறது.")


# Provide the path to your test bird image
test_image_path = "/content/common_pochard_1.jpg"  # Change this to your test image

# Predict and display the results
predict_bird_species(test_image_path)
# Out:
# ✅ Model loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 🦜 Predicted Bird Species: Common Pochard

# %%
from tensorflow.keras.models import load_model
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from IPython.display import display, Image  # For displaying images in Colab

# Load your trained model
model = load_model("/content/final_bird_model.keras")

print("✅ Model loaded successfully!")


def load_and_preprocess_image(image_path):
    img = cv2.imread(image_path)  # Load image
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, (224, 224))  # Resize to 224x224 (for MobileNetV3)
    img = preprocess_input(img)  # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Update this list with your actual class names (same as training classes)
class_labels = ['Bar-headed Goose', 'Common Pochard', 'Eurasian Wigeon', 'Fulvous Whistling Duck', 'Graganey', 'Green-winged Teal', 'Indian Spot-billed Duck', 'Knob-billed Duck', 'Lesser Whistling Duck', 'Northern Pintail', 'Northern Shoveler', 'Tufted Duck', 'asian openbill', 'black headed ibis', 'eurasian spoonbill', 'glossy ibis', 'great white pelican', 'greater flamingo', 'painted stork', 'spot billed pelican']


def predict_bird_species(image_path):
    # Preprocess the image
    input_img = load_and_preprocess_image(image_path)

    # Predict the bird species
    predictions = model.predict(input_img)

    # Get the class with the highest probability
    predicted_class_index = np.argmax(predictions)

    # Get the predicted class label
    predicted_label = class_labels[predicted_class_index]

    # Display the image and prediction
    display(Image(filename=image_path))
    print(f"🦜 Predicted Bird Species: {predicted_label}")

    # Add bird details (English and Tamil)
    if predicted_label == "Bar-headed Goose":
        print("Scientific Name: Anser indicus")
        print("English Details: The Bar-headed Goose is known for its high-altitude migratory flights over the Himalayas.")
        print("Tamil Details: பார்முடி வாத்து அதன் இமயமலையை மீறி உயர்ந்த பறப்புகளுக்குப் புகழ் பெற்றது.")

    elif predicted_label == "Common Pochard":
        print("Scientific Name: Aythya ferina")
        print("English Details: The Common Pochard is a medium-sized diving duck found in temperate regions.")
        print("Tamil Details: சாதாரண போச்சார்ட் என்பது மிதமான பகுதிகளில் காணப்படும் நடுத்தர அளவுள்ள மூழ்கும் வாத்து.")

    elif predicted_label == "Eurasian Wigeon":
        print("Scientific Name: Mareca penelope")
        print("English Details: The Eurasian Wigeon is a dabbling duck with distinctive breeding plumage.")
        print("Tamil Details: யூரேஷியன் விட்ஜியன் என்பது தனித்துவமான இனப்பெருக்க இறகுகளைக் கொண்ட ஒரு வாத்து.")

    elif predicted_label == "Fulvous Whistling Duck":
        print("Scientific Name: Dendrocygna bicolor")
        print("English Details: The Fulvous Whistling Duck is a long-legged duck found in warm freshwater marshes.")
        print("Tamil Details: ஃபுல்வஸ் விசில் வாத்து என்பது நீண்ட கால்களைக் கொண்ட, சூடான இனிய நீர்நிலைகளில் காணப்படும் வாத்து.")
        print("Source: https://www.allaboutbirds.org/guide/Fulvous_Whistling-Duck/overview")

    elif predicted_label == "Garganey":
        print("Scientific Name: Spatula querquedula")
        print("English Details: The Garganey is a small dabbling duck that migrates from Europe and Asia to Africa.")
        print("Tamil Details: கார்கனி என்பது ஐரோப்பா மற்றும் ஆசியாவில் இருந்து ஆப்பிரிக்காவுக்கு இடம்பெயரும் ஒரு சிறிய வாத்து.")

    elif predicted_label == "Green-winged Teal":
        print("Scientific Name: Anas crecca")
        print("English Details: The Green-winged Teal is one of the smallest dabbling ducks, known for its green wing patch.")
        print("Tamil Details: கிரீன்-விங்க்ட் டீல் என்பது அதன் பச்சை இறக்கை தழும்பிற்குப் புகழ் பெற்ற மிகச் சிறிய வாத்துகளில் ஒன்றாகும்.")

    elif predicted_label == "Knob-billed Duck":
        print("Scientific Name: Sarkidiornis melanotos")
        print("English Details: The Knob-billed Duck, also known as the Comb Duck, is recognized by the distinctive knob on its bill.")
        print("Tamil Details: க்னாப்-பில்ல்ட் வாத்து அல்லது கோம்ப் வாத்து அதன் மூக்கில் உள்ள தனித்துவமான குன்றுக்குப் புகழ் பெற்றது.")

    elif predicted_label == "Lesser Whistling Duck":
        print("Scientific Name: Dendrocygna javanica")
        print("English Details: The Lesser Whistling Duck is a nocturnal feeder often found in wetlands and rice fields.")
        print("Tamil Details: லெசர் விசில் வாத்து என்பது இரவு நேர உணவுக்குப் பழகிய, பொதுவாக ஈரநிலங்களிலும் நெல் வயல்களிலும் காணப்படும் வாத்து.")

    elif predicted_label == "Northern Pintail":
        print("Scientific Name: Anas acuta")
        print("English Details: The Northern Pintail is a graceful duck with a long neck and pointed tail feathers.")
        print("Tamil Details: நார்தர்ன் பிண்டெயில் என்பது நீண்ட கழுத்து மற்றும் கூர்மையான வால் இறகுகளைக் கொண்ட ஒரு அழகிய வாத்து.")

    elif predicted_label == "Tufted Duck":
        print("Scientific Name: Aythya fuligula")
        print("English Details: The Tufted Duck is a medium-sized diving duck with a distinctive head tuft.")
        print("Tamil Details: டஃப்டட் வாத்து என்பது தனித்துவமான தலை துடுப்பைக் கொண்ட நடுத்தர அளவுள்ள மூழ்கும் வாத்து.")

    elif predicted_label == "asian openbill":
        print("Scientific Name: Anastomus oscitans")
        print("English Details: The Asian Openbill is a stork species characterized by the gap between its bill halves.")
        print("Tamil Details: ஆசிய ஓபன்பில் என்பது அதன் மூக்கு அரைபாகங்களுக்கிடையில் உள்ள இடைவெளியால் அறியப்படும் ஒரு நாரை இனமாகும்.")

    elif predicted_label == "black headed ibis":
        print("Scientific Name: Threskiornis melanocephalus")
        print("English Details: The Black-headed Ibis is a wading bird commonly found in marshes, swamps, and rice fields.")
        print("Tamil Details: கருப்பு தலை நாரை என்பது பொதுவாக சதுப்பு நிலங்கள், குளங்கள் மற்றும் நெல் வயல்களில் காணப்படும் ஒரு நீர்நிலைப் பறவை.")

    elif predicted_label == "eurasian spoonbill":
        print("Scientific Name: Platalea leucorodia")
        print("English Details: The Eurasian Spoonbill is a wading bird known for its spoon-shaped bill used for foraging.")
        print("Tamil Details: யூரேஷியன் ஸ்பூன்பில் என்பது அதன் கரண்டி வடிவ மூக்கிற்குப் புகழ் பெற்ற ஒரு நீர்நிலைப் பறவை.")

    elif predicted_label == "glossy ibis":
        print("Scientific Name: Plegadis falcinellus")
        print("English Details: The Glossy Ibis is a dark-colored wading bird with iridescent plumage.")
        print("Tamil Details: க்ளாசி ஐபிஸ் என்பது பளிச்சிடும் இறகுகளைக் கொண்ட இருண்ட நிற நீர்நிலைப் பறவை.")

    elif predicted_label == "Great White Pelican":
          print("Scientific Name: Pelecanus onocrotalus")
          print("English Details: The Great White Pelican is one of the largest flying birds, known for its large throat pouch.")
          print("Tamil Details: கிரேட் வைட் பெலிகன் என்பது அதன் பெரிய தொண்டை பைகளுக்குப் புகழ் பெற்ற மிகப்பெரிய பறக்கும் பறவைகளில் ஒன்றாகும்.")

    elif predicted_label == "Greater Flamingo":
          print("Scientific Name: Phoenicopterus roseus")
          print("English Details: The Greater Flamingo is the largest species of flamingo, recognized by its pink plumage.")
          print("Tamil Details: கிரேட்டர் ஃபிளாமிங்கோ என்பது அதன் இளஞ்சிவப்பு இறகுகளால் அறியப்படும் மிகப்பெரிய ஃபிளாமிங்கோ இனமாகும்.")
    elif predicted_label == "painted stork":
          print("Scientific Name: Mycteria leucocephala")
          print("English Details: The Painted Stork is a large wading bird known for its bright pink tertial feathers and long yellow beak.")
          print("Tamil Details: அலங்கார நாரை என்பது அதன் பிரகாசமான இளஞ்சிவப்பு இறக்கைகள் மற்றும் நீண்ட மஞ்சள் மூக்கிற்குப் புகழ் பெற்ற பெரிய நீர்நிலைப் பறவை.")

    elif predicted_label == "Spot-billed Pelican":
          print("Scientific Name: Pelecanus philippensis")
          print("English Details: The Spot-billed Pelican is a large waterbird with a distinctive spotted bill, commonly found in wetlands and lakes.")
          print("Tamil Details: ஸ்பாட்-பில்ல்ட் பெலிகன் என்பது தனித்துவமான புள்ளி மூக்கைக் கொண்ட ஒரு பெரிய நீர்நிலைப் பறவை, பொதுவாக ஈரநிலங்கள் மற்றும் ஏரிகளில் காணப்படுகிறது.")
# Provide the path to your test bird image
test_image_path = "/content/asian_openbil_1.jpg"  # Change this to your test image

# Predict and display the results
predict_bird_species(test_image_path)
# Out:
# ✅ Model loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 🦜 Predicted Bird Species: asian openbill
# Scientific Name: Anastomus oscitans
# English Details: The Asian Openbill is a stork species characterized by the gap between its bill halves.
# Tamil Details: ஆசிய ஓபன்பில் என்பது அதன் மூக்கு அரைபாகங்களுக்கிடையில் உள்ள இடைவெளியால் அறியப்படும் ஒரு நாரை இனமாகும்.

# %%
# !pip install streamlit ngrok pydantic numpy tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 118.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 110.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# !pip install streamlit
# !npm install -g localtunnel
# Out:
# ...
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧
# added 22 packages in 3s
# ⠧
# ⠧3 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
import cv2
from PIL import Image
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# Load the trained model
@st.cache_resource
def load_bird_model():
    return load_model("/content/final_bird_model.keras")

model = load_bird_model()

# Define class labels with additional information
bird_info = {
    'Bar-headed Goose': "Scientific Name: Anser indicus\nHabitat: High-altitude lakes and wetlands\nDetails: The Bar-headed Goose is known for its high-altitude migratory flights over the Himalayas\nபார்முடி வாத்து அதன் இமயமலையை மீறி உயர்ந்த பறப்புகளுக்குப் புகழ் பெற்றது.",
    'Common Pochard': "Scientific Name: Aythya ferina\nHabitat: Freshwater lakes and marshes\nDetails: Common Pochard is a medium-sized diving duck found in temperate regions\nசாதாரண போச்சார்ட் என்பது மிதமான பகுதிகளில் காணப்படும் நடுத்தர அளவுள்ள மூழ்கும் வாத்து.",
    'Eurasian Wigeon': "Scientific Name: Mareca penelope\nHabitat: Wetlands, lakes, and coastal lagoons\nDetails: The Eurasian Wigeon is a dabbling duck with distinctive breeding plumage\nயூரேஷியன் விட்ஜியன் என்பது தனித்துவமான இனப்பெருக்க இறகுகளைக் கொண்ட ஒரு வாத்து.",
    'Fulvous Whistling Duck': "Scientific Name: Dendrocygna bicolor\nHabitat: Marshes, rice fields, and wetlands\nDetails: The Fulvous Whistling Duck is a long-legged duck found in warm freshwater marshes\nDetails: The Fulvous Whistling Duck is a long-legged duck found in warm freshwater marshes",
    'Garganey': "Scientific Name: Spatula querquedula\nHabitat: Freshwater lakes and shallow wetlands\nDetails: The Garganey is a small dabbling duck that migrates from Europe and Asia to Africa\nகார்கனி என்பது ஐரோப்பா மற்றும் ஆசியாவில் இருந்து ஆப்பிரிக்காவுக்கு இடம்பெயரும் ஒரு சிறிய வாத்து.",
    'Green-winged Teal': "Scientific Name: Anas crecca\nHabitat: Marshes, wetlands, and riverbanks\nDetails: The Green-winged Teal is one of the smallest dabbling ducks, known for its green wing patch\nகிரீன்-விங்க்ட் டீல் என்பது அதன் பச்சை இறக்கை தழும்பிற்குப் புகழ் பெற்ற மிகச் சிறிய வாத்துகளில் ஒன்றாகும்.",
    'Indian Spot-billed Duck': "Scientific Name: Anas poecilorhyncha\nHabitat: Lakes, ponds, and rivers\nDetails: The Indian Spot-billed Duck is a freshwater bird found in lakes, ponds, and rivers. It has a distinctive yellow-tipped black bill and a red spot at the base of the bill in males\nஇந்திய ஸ்பாட்-பில்ல்ட் வாத்து ஒரு இனிய நீர்நிலைப் பறவையாகும், இது ஏரிகள், குளங்கள் மற்றும் ஆறுகளில் காணப்படுகிறது. இதன் கருப்பு அலகின் முனையில் மஞ்சள் நிறம் காணப்படும், மேலும் ஆண் வாத்துக்கு சிவப்பு புள்ளி இருக்கும்.",
    'Knob-billed Duck': "Scientific Name: Sarkidiornis melanotos\nHabitat: Marshes, swamps, and wetlands\nDetails: The Knob-billed Duck, also known as the Comb Duck, is recognized by the distinctive knob on its bill\nக்னாப்-பில்ல்ட் வாத்து அல்லது கோம்ப் வாத்து அதன் மூக்கில் உள்ள தனித்துவமான குன்றுக்குப் புகழ் பெற்றது.",
    'Lesser Whistling Duck': "Scientific Name: Dendrocygna javanica\nHabitat: Wetlands, rice fields, and ponds\nDetails: The Lesser Whistling Duck is a nocturnal feeder often found in wetlands and rice fields\nலெசர் விசில் வாத்து என்பது இரவு நேர உணவுக்குப் பழகிய, பொதுவாக ஈரநிலங்களிலும் நெல் வயல்களிலும் காணப்படும் வாத்து.",
    'Northern Pintail': "Scientific Name: Anas acuta\nHabitat: Coastal wetlands, lakes, and rivers\nDetails: The Northern Pintail is a graceful duck with a long neck and pointed tail feathers\nநார்தர்ன் பிண்டெயில் என்பது நீண்ட கழுத்து மற்றும் கூர்மையான வால் இறகுகளைக் கொண்ட ஒரு அழகிய வாத்து.",
    'Northern Shoveler': "Scientific Name: Spatula clypeata\nHabitat: Shallow freshwater wetlands and marshes\nDetails: The Northern Shoveler is a migratory duck recognized by its large, spatula-shaped bill. It feeds by filtering plankton and aquatic insects from water\nநார்தர்ன் ஷவ்லர் என்பது அதன் பெரிய, தட்டையான அலகினால் அடையாளம் காணப்படும் ஒரு இடம்பெயரும் வாத்தாகும். இது நீரில் இருந்து பிளாங்க்டன் மற்றும் நீர்ப்பூச்சிகளை வடிகட்டி உணவாக எடுக்கிறது.",
    'Tufted Duck': "Scientific Name: Aythya fuligula\nHabitat: Lakes, reservoirs, and marshes\nDetails: The Tufted Duck is a medium-sized diving duck with a distinctive head tuft\nடஃப்டட் வாத்து என்பது தனித்துவமான தலை துடுப்பைக் கொண்ட நடுத்தர அளவுள்ள மூழ்கும் வாத்து.",
    'Asian Openbill': "Scientific Name: Anastomus oscitans\nHabitat: Wetlands, rice paddies, and swamps\nDetails:The Asian Openbill is a stork species characterized by the gap between its bill halves\nஆசிய ஓபன்பில் என்பது அதன் மூக்கு அரைபாகங்களுக்கிடையில் உள்ள இடைவெளியால் அறியப்படும் ஒரு நாரை இனமாகும்.",
    'Black-headed Ibis': "Scientific Name: Threskiornis melanocephalus\nHabitat: Wetlands, swamps, and coastal marshes\nDetails:The Black-headed Ibis is a wading bird commonly found in marshes, swamps, and rice fields\nகருப்பு தலை நாரை என்பது பொதுவாக சதுப்பு நிலங்கள், குளங்கள் மற்றும் நெல் வயல்களில் காணப்படும் ஒரு நீர்நிலைப் பறவை.",
    'Eurasian Spoonbill': "Scientific Name: Platalea leucorodia\nHabitat: Marshes, shallow lakes, and estuaries\nDetails: The Eurasian Spoonbill is a wading bird known for its spoon-shaped bill used for foraging\nயூரேஷியன் ஸ்பூன்பில் என்பது அதன் கரண்டி வடிவ மூக்கிற்குப் புகழ் பெற்ற ஒரு நீர்நிலைப் பறவை.",
    'Glossy Ibis': "Scientific Name: Plegadis falcinellus\nHabitat: Wetlands, marshes, and coastal areas\nDetails: The Glossy Ibis is a dark-colored wading bird with iridescent plumage\nக்ளாசி ஐபிஸ் என்பது பளிச்சிடும் இறகுகளைக் கொண்ட இருண்ட நிற நீர்நிலைப் பறவை.",
    'Great White Pelican': "Scientific Name: Pelecanus onocrotalus\nHabitat: Lakes, swamps, and estuaries\nDetails: The Great White Pelican is one of the largest flying birds, known for its large throat pouch\nகிரேட் வைட் பெலிகன் என்பது அதன் பெரிய தொண்டை பைகளுக்குப் புகழ் பெற்ற மிகப்பெரிய பறக்கும் பறவைகளில் ஒன்றாகும்.",
    'Greater Flamingo': "Scientific Name: Phoenicopterus roseus\nHabitat: Salt pans, lagoons, and mudflats\nDetails: The Greater Flamingo is the largest species of flamingo, recognized by its pink plumage\nகிரேட்டர் ஃபிளாமிங்கோ என்பது அதன் இளஞ்சிவப்பு இறகுகளால் அறியப்படும் மிகப்பெரிய ஃபிளாமிங்கோ இனமாகும்.",
    'Painted Stork': "Scientific Name: Mycteria leucocephala\nHabitat: Marshes, rivers, and lakes\nDetails: The Painted Stork is a large wading bird known for its bright pink tertial feathers and long yellow beak\nஅலங்கார நாரை என்பது அதன் பிரகாசமான இளஞ்சிவப்பு இறக்கைகள் மற்றும் நீண்ட மஞ்சள் மூக்கிற்குப் புகழ் பெற்ற பெரிய நீர்நிலைப் பறவை.",
    'Spot-billed Pelican': "Scientific Name: Pelecanus philippensis\nHabitat: Freshwater lakes, reservoirs, and rivers\nDetails: The Spot-billed Pelican is a large waterbird with a distinctive spotted bill, commonly found in wetlands and lakes\nஸ்பாட்-பில்ல்ட் பெலிகன் என்பது தனித்துவமான புள்ளி மூக்கைக் கொண்ட ஒரு பெரிய நீர்நிலைப் பறவை, பொதுவாக ஈரநிலங்கள் மற்றும் ஏரிகளில் காணப்படுகிறது."
}

# Function to load and preprocess image
def load_and_preprocess_image(image_path):
    img = cv2.imread(image_path)  # Read image
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, (224, 224))  # Resize for MobileNetV3
    img = preprocess_input(img)  # Normalize
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Function to predict bird species
def predict_bird_species(image_path):
    input_img = load_and_preprocess_image(image_path)
    predictions = model.predict(input_img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = list(bird_info.keys())[predicted_class_index]
    return predicted_label

# Streamlit Web App UI
st.title("🐦 Bird Identification Web App")
st.write("Upload an image to identify the bird species.")

uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "png", "jpeg"])

if uploaded_file is not None:
    # Save uploaded image to disk for OpenCV processing
    file_path = "uploaded_image.jpg"
    with open(file_path, "wb") as f:
        f.write(uploaded_file.getbuffer())

    # Display Uploaded Image
    img = Image.open(uploaded_file)
    st.image(img, caption="Uploaded Image", use_column_width=True)

    # Predict Bird Species
    predicted_class = predict_bird_species(file_path)
    bird_details = bird_info.get(predicted_class, "Information not available")

    # Display Prediction with multiple lines
    st.subheader(f"Prediction: **{predicted_class}**")
    st.text(bird_details)
# Out:
# Writing app.py

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("2upygkrrdNGAu6Yezr24a6K6Dj8_JLV6r6bmw7zc2Ees8rNK")

# %%
# !nohup streamlit run app.py &
# Out:
# nohup: appending output to 'nohup.out'

# %%
from pyngrok import ngrok
public_url = ngrok.connect(8501, "http")
print("Your Streamlit App is Live at:", public_url)
# Out:
# Your Streamlit App is Live at: NgrokTunnel: "https://335c-34-87-137-96.ngrok-free.app" -> "http://localhost:8501"

# %%
# !curl http://localhost:4040/api/tunnels
# Out:
# {"tunnels":[{"name":"http-8501-72194090-b1ce-4785-931b-e7604a7d06d4","ID":"eea7a56459bf3c1133292dcdffab6f5c","uri":"/api/tunnels/http-8501-72194090-b1ce-4785-931b-e7604a7d06d4","public_url":"https://18ec-34-148-25-18.ngrok-free.app","proto":"https","config":{"addr":"http://localhost:8501","inspect":true},"metrics":{"conns":{"count":0,"gauge":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0},"http":{"count":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0}}}],"uri":"/api/tunnels"}

# %%
# !kill -9 $(pgrep -f ngrok)
# Out:
# ^C
